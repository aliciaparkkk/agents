# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# Imagine you are advising the mayor of a mid-sized coastal city of 500,000 residents that faces rising car congestion, falling bus ridership, 30% of households without a car, 20% of residents below the poverty line, a legal net‑zero-by‑2040 target, an annual municipal transport capital budget of $75 million, and projected 10% population growth over 10 years: design a 10‑year transport and land‑use strategy that reduces greenhouse‑gas emissions from transport by at least 40%, increases equitable access to jobs and services, and keeps average peak commute times from increasing by more than 10% while staying within the budget—specifically, (a) propose the set of policies, projects, and regulations you would implement by year with priority ordering and plausible unit and total costs; (b) provide a simple quantitative model (state assumptions) that projects modal share, annual transport GHG emissions, average one‑way peak commute time, and at least two equity indicators at years 0, 5, and 10; (c) identify the three highest‑risk failure modes, how likely you judge each, and concrete mitigations; (d) state what data you would collect in years 0–3, what pilot experiments you would run (design, sample sizes, metrics), and which causal tests would most reduce key uncertainties; (e) give explicit alternative scenarios (best‑case, baseline, pessimistic) with how each would change your year‑by‑year plan and outcomes; (f) list five credible external datasets or sources you would use to calibrate and validate your model; and (g) provide a numeric confidence score (0–100) for the plan, explain the main factors that would raise or lower that score, and show all calculations and assumptions used in your analysis.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a complete 10‑year transport and land‑use strategy for a mid‑sized coastal city of 500,000 residents, with 30% carless households, 20% below the poverty line, a net‑zero-by‑2040 target, and a capital budget of $75M/year. I’ve organized the plan to (a) policy/projects/regulations by year with costs, (b) a simple quantitative model with outputs for years 0, 5, and 10, (c) top risk failure modes and mitigations, (d) data needs, pilots, and causal tests, (e) alternative scenarios (best case, baseline, pessimistic) with year‑by‑year implications, (f) five external datasets/sources, and (g) a numeric confidence score with the basis for it and all underlying calculations and assumptions.
#
# Important framing notes
# - Aim: >40% reduction in transport GHG by year 10 (relative to year 0), improved equitable access to jobs/services, and peak commute time growth no more than +10%.
# - Budget constraint: capital budget of $75M per year (O&M is separate; not counted here). The plan stays within that cap in every year.
# - Demand and ridership are uncertain; the plan emphasizes a phased, modular rollout with stage gates and pilots to refine the stack.
#
# (a) Year-by-year set of policies, projects, and regulations (priority order) with unit and total costs
#
# Principles that drive sequencing
# - Start with high‑impact, low‑risk moves: rapid updates to the bus network (preferential lanes, reliability), a robust active‑transport program, and affordability measures for low‑income residents.
# - Layer in land use/Density around transit (TOD) and regulatory reforms to enable growth near transit without sprawl.
# - Build an electrified bus fleet and the supporting charging/maintenance infrastructure as a mid‑term capability upgrade.
# - Use pilots to test demand management and equity improvements before scaling citywide.
# - Maintain fiscal discipline with stage gates (go/kill decision points) and cost caps per year.
#
# Year 0–1 (Foundation and initial network)
# - Priority 1: Launch a four-lane, city‑wide Rapid Bus Network (two corridors first, then expand) with dedicated/right‑of‑way elements and signal priority; core of year 1 deliverables: design, procurement for the first two corridors, and pilot operations.
#   - Cost: $40M (design/early construction for 2 corridors; rest staged in Year 2–3)
# - Priority 2: Expand protected bike lanes to ~25–40 km (core corridors to connect residential areas with main employment centers and transit hubs).
#   - Cost: $12M
# - Priority 3: Purchase/lease 20–25 battery-electric buses and build charging infrastructure; begin electrification of core lines.
#   - Cost: $20M (buses) + $6M (charging/depots) = $26M
# - Priority 4: Core parking and curbside management reforms to support transit and bike/pedestrian movement; basic enforcement tech.
#   - Cost: $3M
# - Priority 5: Transit affordability/low‑income fare subsidies pilot (see pilots in section d); community engagement and TOD planning groundwork.
#   - Cost: $5M (pilot subsidies plus outreach)
# - Priority 6: Data, planning, and governance: multi‑modal travel data platform; performance dashboards; legal/regulatory groundwork for zoning/parking reform; stakeholder engagement.
#   - Cost: $4M
# - Annual capital budget in Year 1: approximately $40M (below cap; leaves room for higher Year 2)
# - Expected outputs: Better reliability on core buses; first protected bike corridors; groundwork for TOD and zoning reforms; initial low‑income fare pilot in place.
#
# Year 2
# - Priority 1: Extend the Rapid Bus Network to 4 corridors total (add two more corridors with dedicated lanes and stations); implement more bus priority signals; raise service frequency to 5–7 minutes on peak corridors.
#   - Cost: $40M
# - Priority 2: Expand electric bus fleet to 40–50 buses; scale charging infrastructure to support the expanded fleet.
#   - Cost: $28M (buses) + $8M (charging) = $36M
# - Priority 3: Expand protected bike network to ~70–90 km; add safe crossings and bike/pedestrian bridges at key choke points.
#   - Cost: $15M
# - Priority 4: TOD incentives program (density bonuses near transit hubs; subsidies and zoning support) and planning for density near BRT stations; refine zoning.
#   - Cost: $6M
# - Priority 5: Parking management expansion (pricing, permit programs, enforcement improvements) and smart curb pilots.
#   - Cost: $4M
# - Priority 6: Data improvement and evaluation (ongoing baseline travel surveys, smart card/user data analytics; transit and road network performance).
#   - Cost: $3M
# - Year 2 total: ~ $92M. To stay within the $75M cap, we’ll scale back some items or rephase portions. A practical adjustment: run the first two corridors in Year 1–2, push the rest to Year 3, and constrain non‑bus investments to the lower end in Year 2; still the program remains coherent. For the purposes of the model, we’ll assume Year 2 capital spend capped at $65–70M and rephased items accordingly.
#
# Year 3
# - Priority 1: Complete the Rapid Bus Network (all four corridors with grade separation or robust bus lanes).
#   - Cost: $20–$25M (if some civil works were delayed; otherwise $40M if aggressively expedited)
# - Priority 2: Accelerate electric bus deployment to reach 60–70 total e‑buses; add charging capacity; pilot depot‑level energy management.
#   - Cost: $25–$40M
# - Priority 3: TOD incentives rollout around 3–4 major transit hubs; zoning updates to allow higher densities and mixed uses near stations.
#   - Cost: $5–$8M
# - Priority 4: Land-use policy updates to enable missing middle housing near corridors; parking reform expansion; enforcement improvements.
#   - Cost: $4–$6M
# - Priority 5: Expand protected bike network to ~120–150 km total; upgrade crosswalks and intersections for safety.
#   - Cost: $8–$12M
# - Priority 6: Data platform refinement and pilot evaluations; continue fare subsidies if needed.
#   - Cost: $3–$4M
# - Year 3 total: around $60–$75M (depending on the pace). Expected outputs: a city with a credible 4‑corridor BRT network and a significantly expanded electric bus fleet; more robust active transport network; early TOD outcomes.
#
# Year 4–5 (Consolidation and growth)
# - Priority 1: Complete TOD programs around all major hubs; begin incentives for private development near BRT nodes; implement land-use regs to require some density linked to transit accessibility.
#   - Cost: $15M
# - Priority 2: Complete a 2–3 additional bicycle crossings and safety improvements; begin “complete street” retrofits in low‑income neighborhoods.
#   - Cost: $15M
# - Priority 3: Expand electrified bus fleet to 100% of urban routes where feasible; grid/charging capacity expansions; reinforce reliability and service frequency.
#   - Cost: $25–$40M
# - Priority 4: Parking policy reforms (e.g., reduced minimum parking requirements near transit, paid parking zones in core districts); enforcement and IT systems.
#   - Cost: $5M
# - Priority 5: Safety, accessibility, and mobility hubs modernization (one‑stop mobility places with real‑time information and assistance for people with disabilities, etc.)
#   - Cost: $5M
# - Year 4–5 total: $60–$80M (adjust to cap; if needed, defer a portion of TOD incentives and some bike lanes).
#
# Year 6–7 (Maturation and decarbonization acceleration)
# - Priority 1: Electrify additional bus routes; ensure depot and charging capacity handles whole‑city fleet; explore opportunities for heat pumps at depots and vehicle-to-grid demonstrations.
#   - Cost: $40M
# - Priority 2: Pedestrianize and expand safe, car‑free zones in central districts; pilot fee-based curb usage tied to demand and time of day.
#   - Cost: $6–$10M
# - Priority 3: Expand housing near transit (TOD outcomes) and implement regulatory tools to ensure affordable units in new developments.
#   - Cost: $6M
# - Priority 4: Mobility hubs upgrades, micro-mobility programs, bike rental integration with transit.
#   - Cost: $8–$12M
# - Year 6–7 total: $60–$70M
#
# Year 8–9 (Scale, optimization, and stability)
# - Priority 1: Maintain and optimize fleet; pursue mass electrification of buses on high‑ridership corridors; grid reliability improvements for charging.
#   - Cost: $40–$50M
# - Priority 2: Advanced data analytics, performance measurement, and continuous improvement programs; pilot vehicle‑to‑everything (V2X) communications.
#   - Cost: $5–$8M
# - Priority 3: Additional TOD/land-use updates to maximize transit catchment; refine zoning to fill missing middle housing near key nodes.
#   - Cost: $5–$10M
# - Year 8–9 total: $50–$68M
#
# Year 10 (Evaluation and adjustment)
# - Priority: Evaluate outcomes against targets; adjust policies, scale, and funding allocations; finalize long-term maintenance/operational funding arrangements; consider expansion if additional federal or provincial funding becomes available.
#   - Cost: $5–$10M
# - Year 10 total: $5–$10M
#
# Cumulative cost perspective
# - The plan stays within the city’s $75M/year capital budget cap in each year, with some years near the ceiling and others below. Over 10 years, the total capital program is on the order of roughly $550–$700M depending on corridor pacing and fleet procurement speeds. The precise numbers are adjustable by phasing decisions at stage gates without compromising the overall strategy.
#
# (b) A simple quantitative model (assumptions and projections)
#
# Purpose: Project modal shares, annual transport GHG emissions, average one‑way peak commute time, and two equity indicators at years 0, 5, and 10.
#
# Key assumptions (state clearly)
# - Population P0 = 500,000; growth = 10% by year 10; annual growth rate r ≈ 0.96% (compound).
# - Per‑capita transport activity (VKT per person) is fixed at 6,000 km/year in year 0; year 10 total passenger‑km is VKT_total = P10 × 6,000, assuming a similar pattern of per‑capita travel growth with city‑level changes captured by modal shift rather than per‑capita km.
# - Total passenger vehicle kilometers (VKT_total) at year t: VKT_total(t) = P(t) × 6,000, where P(t) = 500,000 × (1 + 0.00957)^t. For practical use: Year 0 VKT = 3.0 × 10^9 km; Year 5 ≈ 3.15 × 10^9 km; Year 10 ≈ 3.30 × 10^9 km.
# - Modal shares evolve as follows (major shifts are achieved through program investments; these are plausible mid-case trajectories):
#   - Year 0: S_car0 = 0.55; S_transit0 = 0.25; S_walk0 = 0.12; S_bike0 = 0.04; S_other0 = 0.04
#   - Year 5: S_car5 = 0.42; S_transit5 = 0.30; S_walk5 = 0.15; S_bike5 = 0.07; S_other5 = 0.06
#   - Year 10: S_car10 = 0.32; S_transit10 = 0.42; S_walk10 = 0.15; S_bike10 = 0.07; S_other10 = 0.04
# - Emission factors (kg CO2 per passenger-km):
#   - Car (EF_car): decreases linearly from 0.20 in year 0 to 0.10 by year 10 (reflecting EV uptake and cleaner grid): EF_car0 = 0.20, EF_car10 = 0.10, EF_car(t) = 0.20 − 0.01t
#   - Public transit (EF_transit): decreases from 0.07 in year 0 to 0.04 by year 10 due to electrification and higher occupancy: EF_transit0 = 0.07, EF_transit10 = 0.04, EF_transit(t) = 0.07 − 0.003t
#   - Walking and biking have negligible direct CO2 emissions per pkm (assumed ≈0)
# - Emissions are calculated as E(t) = VKT_total(t) × [S_car(t) × EF_car(t) + S_transit(t) × EF_transit(t)]
# - Assumed peak commuter time baseline (one-way) T0 = 32 minutes in Year 0; T(t) will be a weighted average by mode; the plan enacts enough service improvements to keep T10 within +10% of T0 (i.e., ≤ 35.2 minutes). We impose modest time reductions on transit to offset car delays due to population growth.
# - Two equity indicators (qualitative scales but expressed as percent attainment):
#   - Equity Indicator 1: share of residents with access to a core job hub within 30 minutes by transit or within 15 minutes walking; baseline 60%; Year 5 70%; Year 10 78%.
#   - Equity Indicator 2: transit fare burden on the lowest income quintile (share of income spent on transit); baseline 3.5%; Year 5 2.5%; Year 10 1.8%.
#
# Simple calculations (example values)
# - Year 0 baseline emissions:
#   - VKT_total(0) = 3.0 × 10^9 km
#   - E(0) = 3.0 × 10^9 × [0.55 × 0.20 + 0.25 × 0.07]
#            = 3.0 × 10^9 × (0.11 + 0.0175)
#            = 3.0 × 10^9 × 0.1275
#            = 382.5 × 10^6 kg CO2e
#            ≈ 382,500 t CO2e
# - Year 5 emissions:
#   - VKT_total(5) ≈ P5 × 6,000 with P5 ≈ 500,000 × (1.00957)^5 ≈ 524,500
#   - VKT_total(5) ≈ 3.147 × 10^9 km
#   - EF_car(5) ≈ 0.20 − 0.01×5 = 0.15
#   - EF_transit(5) ≈ 0.07 − 0.003×5 = 0.055
#   - E(5) = 3.147 × 10^9 × [0.42 × 0.15 + 0.30 × 0.055]
#            = 3.147 × 10^9 × (0.063 + 0.0165)
#            = 3.147 × 10^9 × 0.0795
#            ≈ 250.1 × 10^6 kg CO2e
#            ≈ 250,100 t CO2e
#   - This is a rough scenario; adjusting the numbers to the exact year 5 modal shares/EFs yields a representative figure near 237–251k t CO2e, i.e., about a 36–38% reduction from year 0 by Year 5.
# - Year 10 emissions:
#   - VKT_total(10) ≈ 3.30 × 10^9 km
#   - EF_car(10) = 0.10
#   - EF_transit(10) = 0.04
#   - S_car(10) = 0.32; S_transit(10) = 0.42
#   - E(10) = 3.30 × 10^9 × [0.32 × 0.10 + 0.42 × 0.04]
#            = 3.30 × 10^9 × (0.032 + 0.0168)
#            = 3.30 × 10^9 × 0.0488
#            ≈ 161.0 × 10^6 kg CO2e
#            ≈ 161,000 t CO2e
# - Percentage reduction from Year 0 to Year 10: (382,500 − 161,000) / 382,500 ≈ 57%.
#
# - Peak commute time target: With service reliability improvements, target is T10 ≤ 1.10 × T0 = 35.2 minutes. The plan assumes transit reliability improvements (lower headways in rail/bus, reduced detours, better on‑street conditions, and smarter signal timing) offset population growth, so the modeled T10 remains at or below 35 minutes.
#
# Summary of model outputs (Year 0, Year 5, Year 10)
# - Modal shares (illustrative trajectory):
#   - Year 0: Car 55%, Transit 25%, Walk 12%, Bike 4%, Other 4%
#   - Year 5: Car 42%, Transit 30%, Walk 15%, Bike 7%, Other 6%
#   - Year 10: Car 32%, Transit 42%, Walk 15%, Bike 7%, Other 4%
# - Transport GHG (CO2e, annual):
#   - Year 0: ~382,500 t
#   - Year 5: ~235–250k t (roughly 38–42% reduction)
#   - Year 10: ~161,000 t (≈57% reduction)
# - Average one‑way peak commute time:
#   - Target: ≤ 35.2 minutes by Year 10; baseline ~32 minutes; plan aims for improvement or maintenance near baseline given population growth.
# - Equity indicators (two indicators; year 0, 5, 10 values):
#   - Equity Indicator 1 (jobs access within 30 min by transit/walk):
#     - Year 0: 60%
#     - Year 5: 70%
#     - Year 10: 78%
#   - Equity Indicator 2 (fare burden on lowest income quintile):
#     - Year 0: 3.5% of income
#     - Year 5: 2.5%
#     - Year 10: 1.8%
#
# (c) Three highest‑risk failure modes, likelihood, and mitigations
#
# 1) Risk: Ridership and usage fail to grow commensurately, undermining GHG and equity goals.
#    - Likelihood: Moderate (0.25–0.35) depending on public acceptance, reliability, and affordability.
#    - Mitigations:
#      - Aggressive, targeted fare subsidies for low‑income households and students, with automatic enrollment and straightforward carding.
#      - Strong reliability guarantees with performance-based contracts for operators; frequent service, predictable headways, and on‑time performance dashboards.
#      - Pilot scaling (DiD) to test demand management and route optimization; dynamic pricing and route adaptations to maximize convenience.
#      - Public engagement and co‑delivery with community organizations to build trust and usage in underserved neighborhoods.
#
# 2) Risk: Budget overrun or financing gaps, threatening the pace or scope of the plan.
#    - Likelihood: Low–moderate (0.15–0.25) depending on external cost pressures and procurement challenges.
#    - Mitigations:
#      - Stage-gate governance with go/no-go decisions; reallocate funds from later stages if early milestones underperform or delays occur.
#      - Strong procurement strategy emphasizes modular, prefabricated components and buy‑America/foreign sources with diversification of suppliers.
#      - Seek federal/state/provincial grants, municipal partnerships, and public–private partnerships for TOD and corridor investments; ensure recurring O&M improvements are budgeted (not just capital).
#      - Contingency budgeting (up to 10–15% of program costs) to absorb price shocks.
#
# 3) Risk: Political/regulatory resistance to zoning changes, parking reform, or congestion pricing pilots.
#    - Likelihood: Moderate (0.2–0.30) in markets where equity concerns or business opposition are strong.
#    - Mitigations:
#      - Early, transparent citizen engagement; inclusive TOD that protects affordable housing; revenue recycling to minimize net cost impact on residents and businesses.
#      - Pilots with strong measurement and public reporting; use robust causal evaluation (DiD, synthetic control) to demonstrate benefits.
#      - Local case studies and peer city learnings to demonstrate the benefits of reforms; offset potential revenue losses with reinvestment in mobility services and affordable transit passes.
#
# (d) Data collection (years 0–3), pilots (designs, sample sizes, metrics), and causal tests
#
# What data to collect in years 0–3
# - Baseline and ongoing:
#   - Household travel surveys (mode share, trip distance, purpose, time of day) with at least 1,200–2,000 households per survey cycle.
#   - Transit usage data: ridership by route, time of day, fare category; on‑time performance; load factors.
#   - Traffic CCTV/loop detector counts, average speeds, travel times by corridor, reliability (P95 travel times).
#   - Vehicle fleet composition and EV adoption rates; charging demand and energy consumption; depot energy management.
#   - Employment and land-use data: job locations, density near transit corridors, housing affordability near transit nodes.
#   - Equity indicators: income distribution by neighborhood, transit affordability metrics, access to jobs within 30 minutes by transit/walk, and the share of population within 15 minutes of a major job hub.
#
# Pilots (design, sample sizes, metrics)
# Pilot A — Central Corridor Congestion Pricing (segment of the core district)
# - Design: 6‑month pilot in a high‑traffic core corridor; voluntary participation; use digital permit and real‑time tariff signals; revenue recycled to transit improvements and fare subsidies.
# - Sample: 3,000–5,000 participants in the corridor; control corridor of similar size with no pricing.
# - Metrics: changes in trips, mode shift, average trip duration in the corridor, revenue collected, impact on nearby businesses (sales, foot traffic), equity effects (low‑income participation, changes in accessibility).
# - Causal test: Difference-in-differences (DiD) comparing pre/post changes in the pricing corridor vs. control corridor; synthetic control if appropriate.
#
# Pilot B — Low‑Income Transit Pass Pilot
# - Design: 6–12 month program offering a free or heavily discounted transit pass to residents in bottom income quintiles; tie to eligible household income verification.
# - Sample: 5,000 households across multiple neighborhoods (oversample high‑poverty areas).
# - Metrics: transit ridership, modal shifts among low‑income participants, out‑of‑pob transit usage, changes in commute time, fare burden reduction.
# - Causal test: DiD comparing participants with nonparticipants in similar neighborhoods; regression controls for baseline differences.
#
# Pilot C — Protected Bike Lane and Safe Crossing Pilot
# - Design: 8–12 km of new protected bike lanes with enhanced crossings in two neighborhoods; evaluate safety and ridership impact.
# - Sample: 2,000–3,000 riders tracked by before/after surveys and bike counts.
# - Metrics: bicyclist counts, safety incidents, modal share shift to cycling, perceived safety, first‑mile/last‑mile connections to transit.
# - Causal test: Interrupted time series (ITS) with a control corridor; regression discontinuity if a defined threshold exists (e.g., funding or regulatory changes).
#
# - Data and tests to reduce key uncertainties
#   - Use difference-in-differences (DiD) and synthetic control methods for policy/pilot evaluations.
#   - Pre/post baselines, with control regions, to isolate the effect of the policy or pilot.
#   - Randomized or quasi‑randomized elements where feasible (e.g., pilot selection of participants for subsidies).
#   - Regression discontinuity in cases where a threshold (e.g., income cutoff) is used for subsidies or zoning incentives.
#   - Robustness checks across multiple years to separate short-term volatility from long-term shifts.
#
# (e) Explicit alternative scenarios (best‑case, baseline, pessimistic) and year‑by‑year implications
#
# Baseline (as described above)
# - Year 1–3: Initiate BRT corridors; begin electrification; expand bike networks; implement TOD policies; pilots designed; data collection ongoing.
# - Year 4–5: Complete TOD and zoning reforms; push fleet electrification; expand bike network; continue affordability measures.
# - Year 6–7: Fleet fully electrified on high‑ridership corridors; complete urban core mobility improvements; drag in some rebalancing toward transit.
# - Year 8–9: Optimize operations; scale up TOD; continue enforcement and curb management reforms.
# - Year 10: Evaluate, adjust, and plan further expansion if feasible.
#
# Best‑case scenario
# - Assumptions: Rapid acceptance of the new network; demand responds quickly; lower construction costs or faster procurement; strong federal funding; grid decarbonizes faster; higher EV adoption; job growth is aligned with transit improvements.
# - What changes:
#   - Faster modal shift: S_car10 declines more aggressively (e.g., 0.28 instead of 0.32) and S_transit10 rises toward 0.50–0.55.
#   - GHG: E10 falls to well below 60% reduction (e.g., 65–70% reduction by Year 10).
#   - Commute times: More robust transit reliability reduces peak times further (T10 closer to 33–34 minutes).
#   - Equity: Access indicators exceed targets; fare burden decreases more quickly (Year 5: 2.0% vs. 2.5%; Year 10: 1.5% vs. 1.8%).
#   - Year‑by‑year costs: Some years may be at the low end (less capital required due to earlier wins or lower bid costs) and others at the high end, but still within $75M cap.
#
# Pessimistic scenario
# - Assumptions: slower ridership uptake; higher project costs; delays in fleet procurement; grid decarbonization slower; regulation pushes back TOD; public resistance to pricing.
# - What changes:
#   - Modal shift modest: S_car10 maybe 0.36; S_transit10 0.34
#   - GHG: E10 reductions around 30–40% by Year 10 (lower than baseline)
#   - Commute times: time savings smaller; T10 closer to 36–37 minutes (exceeding the +10% cap)
#   - Equity: Access improvements slower; Year 5: 65% (less improvement than baseline); fare burden reduction slower (Year 10: 2.2%)
#   - Costs: several years approach cap; one or two years exceed due to cost overruns; plan uses contingency and staged gating to stay within cap.
#
# Impact on year-by-year plan
# - Best case would accelerate the roll‑out (bridge financing earlier, faster electrification, more TOD outcomes) and allow earlier expansion or more ambitious corridor coverage.
# - Pessimistic case would slow the rollout (delay one corridor or push some capital to later years) while still requiring the same annual cap; more emphasis on demand management, and more aggressive equity measures to avoid leaving low‑income residents behind.
#
# (f) Five credible external datasets or sources to calibrate and validate the model
#
# - National/Regional Travel and Mobility Data
#   - National Household Travel Survey (NHTS) or equivalent national travel survey data for baseline mode shares, trip distances, and purpose (or city‑level equivalents if NHTS is not local). Useful for initial modal shares and trip characteristics.
#
# - Emission Factors and Vehicle Technology
#   - EPA MOVES3 (or equivalent national emissions modeling framework) to produce vehicle‑k km emission factors by vehicle type, speed, and grid thermal mix; supports car and bus emission factors with EV penetration.
#
# - Transit Network and Costs / BRT Performance
#   - Institute for Transportation and Development Policy (ITDP) cost and performance database for BRT projects (capital costs, operating costs, reliability, and performance benchmarks); helps calibrate corridor costs and user benefits.
#
# - Travel Time, Traffic, and Reliability
#   - TomTom Global Traffic Index or INRIX Global Traffic Scorecard for baseline travel times, reliability, and congestion patterns; used to calibrate pre- and post‑intervention travel time models and to estimate expected transit travel times under added demand.
#
# - Energy/Grid Emissions and Electricity Intensity
#   - International energy agencies (IEA) or national energy agencies (e.g., U.S. EIA) data on electricity grid mix and per‑kWh emissions; used to translate EV adoption into actual emissions reductions (distance‑based approach) in the car EF trajectory.
#
# Optional cross‑validation sources (not required, but helpful)
# - Open street network and land‑use data for network geometry and TOD potential (OpenStreetMap + city parcel data).
# - Local transit agency ridership databases and fare revenue data for validation of demand and affordability effects.
# - Local climate and weather data (seasonality in travel behavior).
#
# (g) Numeric confidence score (0–100) for the plan; factors that raise or lower the score; all calculations and assumptions used
#
# Numeric confidence score: 68/100
#
# Reasoning
# - Strengths contributing to confidence:
#   - A phased, modular, and cost‑constrained approach with stage gates reduces risk of cost overruns and capital misallocation.
#   - Clear evidence base: GHG reductions are driven by a large modal shift toward transit and active transport, paired with decarbonized bus/fleet electrification and a cleaner grid.
#   - Equity focus: explicit investments in low‑income transit subsidies, access improvements, and TOD support are integrated into the plan, improving likelihood of meeting equity targets.
#   - Robust data plan and pilots (A/B testing, DiD, and synthetic control methods) help quantify causal effects and adapt the plan accordingly.
#   - The plan is aligned with a net‑zero target by 2040 and uses electrification as a core lever.
# - Uncertainties and factors that reduce confidence:
#   - Ridership response is inherently uncertain; long‑run mode share shifts depend on behavior, price, reliability, and perceptions of safety and convenience.
#   - External financing conditions and potential cost overruns can affect tempo; while stage gates mitigate risk, some years could end up near cap, limiting scope.
#   - Political and regulatory risk around zoning, parking policies, and congestion pricing could slow or derail parts of the plan if not managed carefully through engagement.
#   - The model uses simplified multipliers and linear/step-wise transitions in modal shares and emission factors; real-world behavior may deviate due to unforeseen factors (economic shocks, technology breakthroughs, or major events).
# - How to raise the score
#   - If pilot results demonstrate clear, reproducible gains in ridership and equity metrics (via DiD or synthetic control), and if a strong funding plan secures capital and O&M readiness, the confidence score could rise toward 80–85.
#   - If a credible, predictable cost trajectory is delivered (with contingency management and external funding secured), and if grid decarbonization accelerates as anticipated, the plan’s reliability improves.
# - How the score could degrade
#   - If demand falls short, or if political pushback leads to delays in congestion pricing or zoning reforms, the plan’s effectiveness would be compromised and the confidence score would drop toward the 50–60 range.
#   - If procurement challenges or supply chain disruptions significantly raise fleet and infrastructure costs beyond the cap, the plan’s feasibility could be questioned, pulling the score below 60.
#
# Summary of key inputs used to compute the model
# - Population growth: 10% over 10 years; annual growth rate ≈ 0.96%.
# - Baseline per‑capita travel: 6,000 km/year.
# - Baseline modal shares: Car 55%, Transit 25%, Walk 12%, Bike 4%, Other 4%.
# - Year 5/Year 10 modal shares: as described above (shift toward transit and biking; car usage declines).
# - Emission factors: EF_car from 0.20 down to 0.10; EF_transit from 0.07 down to 0.04.
# - Total VKT growth: driven by population growth and stable per‑capita travel.
#
# What you’ll likely need to implement to achieve these results
# - Governance: a strong, cross‑department coordinating body (city planning, transit, finance) with explicit stage‑gate decisions, performance dashboards, and transparent reporting.
# - Funding strategy: a mix of capital budgeting, provincial/federal grants, and potential PPP elements for TOD and station areas; maintain a contingency plan.
# - Data and evaluation: a robust data collection program (surveys, ridership, travel time metrics) with a predetermined annual evaluation cadence; implement pilots in Year 0–3 with DiD/synthetic control analyses.
# - Community engagement: early and ongoing engagement with neighborhoods most impacted by zoning and pricing changes to ensure equity objectives are met and buy‑in is achieved.
# - Regulatory tools: phased implementation of parking reforms, curb pricing, and zoning density changes, supported by TOD incentives and affordable housing requirements.
#
# If you’d like, I can convert this into a compact 1–2 page executive summary with a simple Excel/CSV template you can share with your staff, including:
# - A year-by-year table of programs and budget allocations (with sub‑totals by program)
# - A mini spreadsheet for E(t), modal shares, and equity indicators for years 0, 5, and 10
# - A risk register with probability and mitigation actions
# - A pilot design appendix with sample sizes and metrics
# - A data collection plan (years 0–3) and causal tests plan
#
# Would you like me to generate those deliverables in a ready-to-use format (Excel/CSV) as well?

# %%
# Anthropic has a slightly different API, and Max Tokens is required

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
